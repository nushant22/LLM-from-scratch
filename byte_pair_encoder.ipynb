# %% [markdown]
# # BYTE PAIR ENCODING

# %% [markdown]
# ### BPE Tokenizer

# %%
! pip3 install tiktoken
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tiktoken in C:\Users\Lenovo\AppData\Roaming\Python\Python314\site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\Lenovo\AppData\Roaming\Python\Python314\site-packages (from tiktoken) (2026.4.4)
# Requirement already satisfied: requests>=2.26.0 in C:\Users\Lenovo\AppData\Roaming\Python\Python314\site-packages (from tiktoken) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Lenovo\AppData\Roaming\Python\Python314\site-packages (from requests>=2.26.0->tiktoken) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Lenovo\AppData\Roaming\Python\Python314\site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Lenovo\AppData\Roaming\Python\Python314\site-packages (from requests>=2.26.0->tiktoken) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Lenovo\AppData\Roaming\Python\Python314\site-packages (from requests>=2.26.0->tiktoken) (2026.2.25)

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit terraces"
    "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print("Encoded integers:", integers)
# Out:
# Encoded integers: [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode
print("Decoded string:", strings(integers))
# Out:
# Decoded string: Hello, do you like tea? <|endoftext|> In the sunlit terracesof someunknownPlace.

# %% [markdown]
# EXAMPLE

# %%
integers = tokenizer.encode("Akwirw ier")
print(integers)

strings = tokenizer.decode(integers)
print(strings)
# Out:
# [33901, 86, 343, 86, 220, 959]
# Akwirw ier
